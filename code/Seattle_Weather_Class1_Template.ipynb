# %% [markdown]
# # Load and explore the data

# %% [markdown]
# ## Import libraries

# %%
# Import pandas, numpy, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# seaborn is a data visualization library built on matplotlib
import seaborn as sns

# set the plotting style
sns.set_style("whitegrid")

# %% [markdown]
# ## Load the data

# %% [markdown]
# ##### Load the Seattle data set

# %%
df_seattle = pd.read_csv('https://raw.githubusercontent.com/brian-fischer/DATA-5100/refs/heads/main/weather/seattle_rain.csv')

# %%
type(df_seattle)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##### Load the NEW YORK data set

# %%
df_Newyork = pd.read_csv('https://raw.githubusercontent.com/Hemantkumaar/weather_1/refs/heads/main/data/nyc_rain_4132986.csv')

# %%
type(df_Newyork)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Explore the contents of the data sets

# %%
df_seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1658 entries, 0 to 1657
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  1658 non-null   object
#  1   NAME     1658 non-null   object
#  2   DATE     1658 non-null   object
#  3   DAPR     23 non-null     float64
#  4   MDPR     23 non-null     float64
#  5   PRCP     1636 non-null   float64
#  6   SNOW     353 non-null    float64
#  7   SNWD     66 non-null     float64
#  8   WESD     15 non-null     float64
#  9   WESF     28 non-null     float64
# dtypes: float64(7), object(3)
# memory usage: 129.7+ KB

# %%
df_Newyork.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  1826 non-null   object
#  1   NAME     1826 non-null   object
#  2   DATE     1826 non-null   object
#  3   PRCP     1826 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 57.2+ KB

# %% [markdown]
# ##### Start by looking at the head of each data frame.
#
# This will let us see the names of the columns and a few example values for each column.

# %% [markdown]
# ##### Examine more rows

# %% [markdown]
# ##### St. Louis data set

# %% [markdown]
# ##### Are the columns are the same?

# %% [markdown]
# ##### Use the `info` method to check the data types, size of the data frame, and numbers of missing values.

# %% [markdown]
# ##### St. Louis data set

# %% [markdown]
# ##### We can also compare data frame sizes using the shape attribute

# %%
df_seattle.shape[0]
# Out:
# 1658

# %%
df_seattle.shape
# Out:
# (1658, 10)

# %%
df_Newyork.shape
# Out:
# (1826, 4)

# %% [markdown]
# ## Why might the St. Louis data set be larger?

# %% [markdown]
# <pre>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </pre>

# %% [markdown]
# #### Examine the `STATION` column

# %%
df_Newyork['STATION']
# Out:
# 0       USW00094728
# 1       USW00094728
# 2       USW00094728
# 3       USW00094728
# 4       USW00094728
#            ...
# 1821    USW00094728
# 1822    USW00094728
# 1823    USW00094728
# 1824    USW00094728
# 1825    USW00094728
# Name: STATION, Length: 1826, dtype: object

# %%
df_seattle['STATION']
# Out:
# 0       US1WAKG0225
# 1       US1WAKG0225
# 2       US1WAKG0225
# 3       US1WAKG0225
# 4       US1WAKG0225
#            ...
# 1653    US1WAKG0225
# 1654    US1WAKG0225
# 1655    US1WAKG0225
# 1656    US1WAKG0225
# 1657    US1WAKG0225
# Name: STATION, Length: 1658, dtype: object

# %% [markdown]
# ##### How many unique stations are present?

# %%
df_seattle['STATION'].unique()
# Out:
# array(['US1WAKG0225'], dtype=object)

# %%
df_Newyork['STATION'].unique()
# Out:
# array(['USW00094728'], dtype=object)

# %%
df_seattle['STATION'].nunique()
# Out:
# 1

# %%
df_Newyork['STATION'].nunique()
# Out:
# 1

# %% [markdown]
# #### Examine the `DATE` column

# %%
df_seattle['DATE']
# Out:
# 0         1/1/18
# 1         1/2/18
# 2         1/3/18
# 3         1/4/18
# 4         1/5/18
#           ...
# 1653    12/27/22
# 1654    12/28/22
# 1655    12/29/22
# 1656    12/30/22
# 1657    12/31/22
# Name: DATE, Length: 1658, dtype: object

# %%
df_Newyork['DATE']
# Out:
# 0       2018-01-01
# 1       2018-01-02
# 2       2018-01-03
# 3       2018-01-04
# 4       2018-01-05
#            ...
# 1821    2022-12-27
# 1822    2022-12-28
# 1823    2022-12-29
# 1824    2022-12-30
# 1825    2022-12-31
# Name: DATE, Length: 1826, dtype: object

# %% [markdown]
# ### Be careful to use correct data types

# %% [markdown]
# ### Convert `DATE` to datetime

# %%
df_seattle['DATE'].max
# Out:
# <bound method Series.max of 0         1/1/18
# 1         1/2/18
# 2         1/3/18
# 3         1/4/18
# 4         1/5/18
#           ...
# 1653    12/27/22
# 1654    12/28/22
# 1655    12/29/22
# 1656    12/30/22
# 1657    12/31/22
# Name: DATE, Length: 1658, dtype: object>

# %%
df_Newyork['DATE'].max
# Out:
# <bound method Series.max of 0       2018-01-01
# 1       2018-01-02
# 2       2018-01-03
# 3       2018-01-04
# 4       2018-01-05
#            ...
# 1821    2022-12-27
# 1822    2022-12-28
# 1823    2022-12-29
# 1824    2022-12-30
# 1825    2022-12-31
# Name: DATE, Length: 1826, dtype: object>

# %%
df_seattle['DATE'] = pd.to_datetime(df_seattle['DATE'])
# Out:
# /tmp/ipython-input-3087519436.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_seattle['DATE'] = pd.to_datetime(df_seattle['DATE'])

# %%
df_Newyork['DATE'] = pd.to_datetime(df_Newyork['DATE'])

# %%
df_Newyork['DATE']
# Out:
# 0      2018-01-01
# 1      2018-01-02
# 2      2018-01-03
# 3      2018-01-04
# 4      2018-01-05
#           ...
# 1821   2022-12-27
# 1822   2022-12-28
# 1823   2022-12-29
# 1824   2022-12-30
# 1825   2022-12-31
# Name: DATE, Length: 1826, dtype: datetime64[ns]

# %%
df_seattle['DATE']
# Out:
# 0      2018-01-01
# 1      2018-01-02
# 2      2018-01-03
# 3      2018-01-04
# 4      2018-01-05
#           ...
# 1653   2022-12-27
# 1654   2022-12-28
# 1655   2022-12-29
# 1656   2022-12-30
# 1657   2022-12-31
# Name: DATE, Length: 1658, dtype: datetime64[ns]

# %% [markdown]
# ### What range of dates are present?

# %%
df_seattle['DATE'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df_Newyork['DATE'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df_seattle['DATE'].max()
# Out:
# Timestamp('2022-12-31 00:00:00')

# %%
df_seattle['DATE'].max()
# Out:
# Timestamp('2022-12-31 00:00:00')

# %%
df_seattle['DATE'].agg(['min','max'])
# Out:
# min   2018-01-01
# max   2022-12-31
# Name: DATE, dtype: datetime64[ns]

# %%
df_Newyork['DATE'].agg(['min','max'])
# Out:
# min   2018-01-01
# max   2022-12-31
# Name: DATE, dtype: datetime64[ns]

# %% [markdown]
# ### Are the data suitable for answering the question?

# %% [markdown]
# Plot the daily precipitation data for Seattle.

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=df_seattle, x='DATE', y='PRCP')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Precipitation (inch)',fontsize=18)
plt.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# ##### Plot the daily precipitation data for NEWYORK

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=df_Newyork, x='DATE', y='PRCP')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Precipitation (inch)',fontsize=18)
plt.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# ## Tutorial: Selecting subsets of a DataFrame

# %%
df_seattle.head()
# Out:
#        STATION                    NAME       DATE  DAPR  MDPR  PRCP  SNOW  \
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-01   NaN   NaN  0.00   NaN
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-02   NaN   NaN  0.00   NaN
# 2  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-03   NaN   NaN  0.00   NaN
# 3  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-04   NaN   NaN  0.00   NaN
# 4  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-05   NaN   NaN  0.25   NaN
#
#    SNWD  WESD  WESF
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN

# %%
df_Newyork.head()
# Out:
#        STATION                         NAME       DATE  PRCP
# 0  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-01  0.00
# 1  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-02  0.00
# 2  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-03  0.00
# 3  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-04  0.76
# 4  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-05  0.00

# %% [markdown]
# ### Select one column

# %% [markdown]
# Select the column containing precipitation `PRCP`.

# %% [markdown]
# #### Use dictionary-style indexing

# %% [markdown]
# #### Use explicit array-style indexing with loc

# %% [markdown]
# #### Use implicit array-style indexing with `.iloc`

# %% [markdown]
# What number column, starting with 0, is `PRCP`?

# %%
df_seattle.head()

# %% [markdown]
# ##### Use implicit array-style indexing with `.iloc`

# %% [markdown]
# ### Select multiple columns

# %% [markdown]
# Select the columns containing `STATION`, `DATE`, and precipitation `PRCP`.

# %% [markdown]
# ##### Use .loc

# %% [markdown]
# ##### Use .iloc

# %% [markdown]
# #### Select a range of columns

# %% [markdown]
# Select all columns from `STATION` through `PRCP`

# %% [markdown]
# ##### Use .iloc

# %% [markdown]
# ### Select the first $n$ rows

# %% [markdown]
# Select the first 3 rows

# %% [markdown]
# Use the `.head()` method

# %% [markdown]
# ##### Use explicit indexing

# %% [markdown]
# ##### Use implicit indexing

# %% [markdown]
# ### Select the last $n$ rows

# %% [markdown]
# Use the `.tail()` method

# %% [markdown]
# ##### Use explicit indexing

# %% [markdown]
# ##### Use implicit indexing

# %% [markdown]
# ### Select rows using logical indexing

# %% [markdown]
# Select the rows where `PRCP` is greater than 0.

# %% [markdown]
# ##### Select the rows where the precipitation is between 0.5 and 0.75 inches.

# %% [markdown]
# ## Select relevant subsets of the data

# %% [markdown]
# We saw that the NEWYORK data set contains data prior to 2018.

# %%
df_stlouis=df_Newyork.loc[df_Newyork['DATE'] <= '2018-01-01']

# %%
df_Newyork.head()
# Out:
#        STATION                         NAME       DATE  PRCP
# 0  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-01  0.00
# 1  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-02  0.00
# 2  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-03  0.00
# 3  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-04  0.76
# 4  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-05  0.00

# %% [markdown]
# ##### Limit the NEWYORK data to 2018 and beyond.

# %%
df_Newyork=df_Newyork.loc[df_Newyork['DATE'] >= '2018-01-01']

# %%
df_Newyork.head()
# Out:
#        STATION                         NAME       DATE  PRCP
# 0  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-01  0.00
# 1  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-02  0.00
# 2  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-03  0.00
# 3  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-04  0.76
# 4  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-05  0.00

# %% [markdown]
# ##### The St. Louis data set has values for many weather stations, while the Seattle data set has only one weather station.
#
# We will focus on the data from the airport in St. Louis.

# %% [markdown]
# ## Join data frames keeping `DATE` and `PRCP` columns

# %%
df_seattle.head(2)
# Out:
#        STATION                    NAME       DATE  DAPR  MDPR  PRCP  SNOW  \
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-01   NaN   NaN   0.0   NaN
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-02   NaN   NaN   0.0   NaN
#
#    SNWD  WESD  WESF
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN

# %%
df_Newyork.head(2)
# Out:
#        STATION                         NAME       DATE  PRCP
# 0  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-01   0.0
# 1  USW00094728  NY CITY CENTRAL PARK, NY US 2018-01-02   0.0

# %% [markdown]
# **What type of join should we do?**

# %%
df = df_Newyork[['DATE','PRCP']].merge(df_Newyork[['DATE','PRCP']], how='outer', on='DATE')

# %%
df.head()
# Out:
#         DATE  PRCP_x  PRCP_y
# 0 2018-01-01    0.00    0.00
# 1 2018-01-02    0.00    0.00
# 2 2018-01-03    0.00    0.00
# 3 2018-01-04    0.76    0.76
# 4 2018-01-05    0.00    0.00

# %%
df.shape
# Out:
# (1826, 3)

# %% [markdown]
# ##### Use a join to keep all dates present

# %% [markdown]
# Each DataFrame had a column named `PRCP`, so the default is to add suffixes _x and _y to differentiate the columns. Normally, I would rename the columns at this point to something more informative. However, I know that I want to convert the DataFrame to a tidy format and I will modify the names later.

# %% [markdown]
# ### Create a tidy data frame with columns for city and precipitation

# %%
df
# Out:
#            DATE  PRCP_x  PRCP_y
# 0    2018-01-01    0.00    0.00
# 1    2018-01-02    0.00    0.00
# 2    2018-01-03    0.00    0.00
# 3    2018-01-04    0.76    0.76
# 4    2018-01-05    0.00    0.00
# ...         ...     ...     ...
# 1821 2022-12-27    0.00    0.00
# 1822 2022-12-28    0.00    0.00
# 1823 2022-12-29    0.00    0.00
# 1824 2022-12-30    0.00    0.00
# 1825 2022-12-31    0.28    0.28
#
# [1826 rows x 3 columns]

# %%
df = pd.melt(df, id_vars=['DATE'], var_name='city', value_name='precipitation')

# %% [markdown]
# How did this change the DataFrame?

# %%
df.head()
# Out:
#         DATE    city  precipitation
# 0 2018-01-01  PRCP_x           0.00
# 1 2018-01-02  PRCP_x           0.00
# 2 2018-01-03  PRCP_x           0.00
# 3 2018-01-04  PRCP_x           0.76
# 4 2018-01-05  PRCP_x           0.00

# %%
df.tail()
# Out:
#            DATE    city  precipitation
# 3647 2022-12-27  PRCP_y           0.00
# 3648 2022-12-28  PRCP_y           0.00
# 3649 2022-12-29  PRCP_y           0.00
# 3650 2022-12-30  PRCP_y           0.00
# 3651 2022-12-31  PRCP_y           0.28

# %% [markdown]
# ### Rename columns or values to follow best practices

# %% [markdown]
# Rename the city values 'NY' and 'SEA'

# %%
df.loc[df['city'] == 'PRCP_x', 'city'] = 'STL'

# %%
df.loc[df['city'] == 'PRCP_y', 'city'] = 'NY'

# %%
df.tail()
# Out:
#            DATE city  precipitation
# 3647 2022-12-27   NY           0.00
# 3648 2022-12-28   NY           0.00
# 3649 2022-12-29   NY           0.00
# 3650 2022-12-30   NY           0.00
# 3651 2022-12-31   NY           0.28

# %%
df.head()
# Out:
#         DATE city  precipitation
# 0 2018-01-01  STL           0.00
# 1 2018-01-02  STL           0.00
# 2 2018-01-03  STL           0.00
# 3 2018-01-04  STL           0.76
# 4 2018-01-05  STL           0.00

# %% [markdown]
# ##### Rename the columns to be lowercase using `df.rename()`

# %% [markdown]
# ## Identify and fill in missing values

# %% [markdown]
# Data can be missing in multiple manners:
# 1. Values are `NaN` in the data frame

# %% [markdown]
# 2.  Values are not included in the data set.

# %% [markdown]
# ### Count the non-null or null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           3652 non-null   datetime64[ns]
#  1   city           3652 non-null   object
#  2   precipitation  3652 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 85.7+ KB

# %%
df.notna().sum()
# Out:
# DATE             3652
# city             3652
# precipitation    3652
# dtype: int64

# %% [markdown]
# Determine the number of non-null values in each column.

# %%
df.isna().sum()
# Out:
# DATE             0
# city             0
# precipitation    0
# dtype: int64

# %% [markdown]
# ##### Determine the number of null values in each column.

# %% [markdown]
# ##### Determine the number of null precipitation values for Seattle and St. Louis.

# %%
df.loc[df['city'] == 'SEA' , 'precipitation'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### The St. Louis data set does not have any `NaN` values of `precipitation`. Are any dates omitted?
#
# **How many data points should we have from 2018 to 2022?**

# %% [markdown]
# ### Impute missing values

# %% [markdown]
# over 5 years 5 x 365 +1 = 1826

# %% [markdown]
# We will replace missing values with the mean across years of values on that day.
#
#
# **Design an algorithm for replacing missing values with the mean across years of values on that day.**

# %% [markdown]
# ## Export the clean .csv file

# %%
df.to_csv('clean_seattle_Newyork_weather.csv', encoding='utf-8-sig', index=False)
